# %%
cred_crd <- read.csv(file="D:\\R_TXT_MINE_DATA\\creditcard.csv", header = TRUE,
                 stringsAsFactors = FALSE,
                 strip.white = TRUE ,
                 sep = ',')
cred_crd-
print(str(cred_crd))
# Out:
# 'data.frame':	284807 obs. of  31 variables:
#  $ Time  : num  0 0 1 1 2 2 4 7 7 9 ...
#  $ V1    : num  -1.36 1.192 -1.358 -0.966 -1.158 ...
#  $ V2    : num  -0.0728 0.2662 -1.3402 -0.1852 0.8777 ...
#  $ V3    : num  2.536 0.166 1.773 1.793 1.549 ...
#  $ V4    : num  1.378 0.448 0.38 -0.863 0.403 ...
#  $ V5    : num  -0.3383 0.06 -0.5032 -0.0103 -0.4072 ...
#  $ V6    : num  0.4624 -0.0824 1.8005 1.2472 0.0959 ...
#  $ V7    : num  0.2396 -0.0788 0.7915 0.2376 0.5929 ...
#  $ V8    : num  0.0987 0.0851 0.2477 0.3774 -0.2705 ...
#  $ V9    : num  0.364 -0.255 -1.515 -1.387 0.818 ...
#  $ V10   : num  0.0908 -0.167 0.2076 -0.055 0.7531 ...
#  $ V11   : num  -0.552 1.613 0.625 -0.226 -0.823 ...
#  $ V12   : num  -0.6178 1.0652 0.0661 0.1782 0.5382 ...
#  $ V13   : num  -0.991 0.489 0.717 0.508 1.346 ...
#  $ V14   : num  -0.311 -0.144 -0.166 -0.288 -1.12 ...
#  $ V15   : num  1.468 0.636 2.346 -0.631 0.175 ...
#  $ V16   : num  -0.47 0.464 -2.89 -1.06 -0.451 ...
# ...

# %%
scale(cred_crd, center = TRUE, scale = TRUE)
# Out:
#       Time      V1          V2           V3          V4          V5
#  [1,] -1.996580 -0.6942411  -0.04407485   1.67277056  0.97336381 -0.245116153
#  [2,] -1.996580  0.6084953   0.16117564   0.10979691  0.31652237  0.043483276
#  [3,] -1.996558 -0.6934992  -0.81157640   1.16946644  0.26823082 -0.364571146
#  [4,] -1.996558 -0.4933240  -0.11216923   1.18251437 -0.60972557 -0.007468867
#  [5,] -1.996537 -0.5913287   0.53154012   1.02140988  0.28465490 -0.295014918
#  [6,] -1.996537 -0.2174742   0.58167387   0.75258406 -0.11883312  0.305008424
#  [7,] -1.996495  0.6277941   0.08538895   0.02992292  0.84938161  0.139019339
#  [8,] -1.996432 -0.3289278   0.85869084   0.70857499 -0.34763044  0.687510480
#  [9,] -1.996432 -0.4565722   0.17329117  -0.07465249 -0.19177354  1.934145971
# [10,] -1.996390 -0.1726974   0.67800373   0.68878028 -0.15692648  0.361790971
# [11,] -1.996369  0.7398003  -0.71236766   0.60270853 -0.97160618 -1.428283159
# ...

# %%
summary(cred_crd)
# Out:
#       Time              V1                  V2                  V3
#  Min.   :     0   Min.   :-56.40751   Min.   :-72.71573   Min.   :-48.3256
#  1st Qu.: 54202   1st Qu.: -0.92037   1st Qu.: -0.59855   1st Qu.: -0.8904
#  Median : 84692   Median :  0.01811   Median :  0.06549   Median :  0.1799
#  Mean   : 94814   Mean   :  0.00000   Mean   :  0.00000   Mean   :  0.0000
#  3rd Qu.:139321   3rd Qu.:  1.31564   3rd Qu.:  0.80372   3rd Qu.:  1.0272
#  Max.   :172792   Max.   :  2.45493   Max.   : 22.05773   Max.   :  9.3826
#        V4                 V5                   V6                 V7
#  Min.   :-5.68317   Min.   :-113.74331   Min.   :-26.1605   Min.   :-43.5572
#  1st Qu.:-0.84864   1st Qu.:  -0.69160   1st Qu.: -0.7683   1st Qu.: -0.5541
#  Median :-0.01985   Median :  -0.05434   Median : -0.2742   Median :  0.0401
#  Mean   : 0.00000   Mean   :   0.00000   Mean   :  0.0000   Mean   :  0.0000
#  3rd Qu.: 0.74334   3rd Qu.:   0.61193   3rd Qu.:  0.3986   3rd Qu.:  0.5704
# ...

# %%
credt_crd<-cred_crd[c(1:31)]
head(credt_crd)
# Out:
#   Time V1         V2          V3        V4         V5          V6
# 1 0    -1.3598071 -0.07278117 2.5363467  1.3781552 -0.33832077  0.46238778
# 2 0     1.1918571  0.26615071 0.1664801  0.4481541  0.06001765 -0.08236081
# 3 1    -1.3583541 -1.34016307 1.7732093  0.3797796 -0.50319813  1.80049938
# 4 1    -0.9662717 -0.18522601 1.7929933 -0.8632913 -0.01030888  1.24720317
# 5 2    -1.1582331  0.87773675 1.5487178  0.4030339 -0.40719338  0.09592146
# 6 2    -0.4259659  0.96052304 1.1411093 -0.1682521  0.42098688 -0.02972755
#   V7          V8          V9         ... V21          V22          V23
# 1  0.23959855  0.09869790  0.3637870 ... -0.018306778  0.277837576 -0.11047391
# 2 -0.07880298  0.08510165 -0.2554251 ... -0.225775248 -0.638671953  0.10128802
# 3  0.79146096  0.24767579 -1.5146543 ...  0.247998153  0.771679402  0.90941226
# 4  0.23760894  0.37743587 -1.3870241 ... -0.108300452  0.005273597 -0.19032052
# ...

# %%
library(DataExplorer)
plot_str(credt_crd)

# %%
plot_missing(credt_crd)
# Out:
# plot without title

# %%
plot_histogram(credt_crd)
# Out:
# plot without title
# plot without title

# %%
plot_density(credt_crd)
# Out:
# plot without title
# plot without title

# %%
plot_correlation(credt_crd, type = 'continuous')
# Out:
# plot without title

# %%
co<-cor(credt_crd)
scale(co,center = T, scale = TRUE)
# Out:
#        Time        V1         V2          V3          V4         V5
# Time    4.49185749  0.4902136 -0.13700674 -2.07797321 -0.7765485  0.7624773
# V1      0.50039150  5.1948264 -0.08574421 -0.02782364 -0.1993417 -0.1128571
# V2     -0.07842578 -0.1355533  4.75338997 -0.02782364 -0.1993417 -0.1128571
# V3     -1.92819002 -0.1355533 -0.08574421  4.85792654 -0.1993417 -0.1128571
# V4     -0.50654502 -0.1355533 -0.08574421 -0.02782364  5.2842763 -0.1128571
# V5      0.75217850 -0.1355533 -0.08574421 -0.02782364 -0.1993417  4.9447708
# V6     -0.31550295 -0.1355533 -0.08574421 -0.02782364 -0.1993417 -0.1128571
# V7      0.35259151 -0.1355533 -0.08574421 -0.02782364 -0.1993417 -0.1128571
# V8     -0.19761801 -0.1355533 -0.08574421 -0.02782364 -0.1993417 -0.1128571
# V9     -0.06968451 -0.1355533 -0.08574421 -0.02782364 -0.1993417 -0.1128571
# V10     0.10794115 -0.1355533 -0.08574421 -0.02782364 -0.1993417 -0.1128571
# ...
